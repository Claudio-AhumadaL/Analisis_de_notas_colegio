# %%
# Import necessary libraries

import pandas as pd
import numpy as np

# %%
# Data loading

notas_data = pd.read_csv('Análisis de notas.csv', sep = ';', encoding = "utf-8-sig", na_values=['#VALUE!', '#DIV/0!'])
notas_data.head()
# Out:
#    n_alumno género       curso                               asignatura  \
# 0       1.0      F  1ero Medio  Historia, Geografía y Ciencias Sociales
# 1       2.0      M  1ero Medio  Historia, Geografía y Ciencias Sociales
# 2       3.0      M  1ero Medio  Historia, Geografía y Ciencias Sociales
# 3       4.0      M  1ero Medio  Historia, Geografía y Ciencias Sociales
# 4       5.0      M  1ero Medio  Historia, Geografía y Ciencias Sociales
#
#          eval  analizar_correctas  analizar_incorrectas  \
# 0  sumativa 1                 2.0                   1.0
# 1  sumativa 1                 3.0                   0.0
# 2  sumativa 1                 1.0                   2.0
# 3  sumativa 1                 3.0                   0.0
# 4  sumativa 1                 2.0                   1.0
#
#    identificar_correctas  identificar_incorrectas  comprender_correctas  ...  \
# 0                    0.0                      3.0                   4.0  ...
# ...

# %%
# Preliminary Inspection

print(notas_data.dtypes)
print(notas_data.describe(include='all'))
# Out:
# n_alumno                         float64
# género                            object
# curso                             object
# asignatura                        object
# eval                              object
# analizar_correctas               float64
# analizar_incorrectas             float64
# identificar_correctas            float64
# identificar_incorrectas          float64
# comprender_correctas             float64
# comprender_incorrectas           float64
# caracterizar_correctas           float64
# caracterizar_incorrectas         float64
# aplicar_correctas                float64
# aplicar_incorrectas              float64
# puntaje_obtenido_alternativas    float64
# puntaje_obtenido_desarrollo      float64
# porcentaje_analizar               object
# porcentaje_identificar            object
# porcentaje_comprender             object
# porcentaje_caracterizar           object
# porcentaje_aplicar                object
# porcentaje_alternativas           object
# ...

# %%
# Change types to correct ones

   ## n_alumno (float to string)
    
notas_data.astype({'n_alumno': 'object'})

   ## Transform percentages to correct syntax (0 < x < 1)
    
#notas_data['porcentaje_analizar'] = notas_data['porcentaje_analizar'].str.replace('%', '')
#notas_data['porcentaje_analizar'] = notas_data.astype({'porcentaje_analizar' : 'float64'})
#notas_data['porcentaje_analizar'] = notas_data['porcentaje_analizar'].apply(lambda x: x*0.01)

notas_data.dtypes
# Out:
# n_alumno                         float64
# género                            object
# curso                             object
# asignatura                        object
# eval                              object
# analizar_correctas               float64
# analizar_incorrectas             float64
# identificar_correctas            float64
# identificar_incorrectas          float64
# comprender_correctas             float64
# comprender_incorrectas           float64
# caracterizar_correctas           float64
# caracterizar_incorrectas         float64
# aplicar_correctas                float64
# aplicar_incorrectas              float64
# puntaje_obtenido_alternativas    float64
# puntaje_obtenido_desarrollo      float64
# porcentaje_analizar               object
# porcentaje_identificar            object
# porcentaje_comprender             object
# porcentaje_caracterizar           object
# porcentaje_aplicar                object
# porcentaje_alternativas           object
# ...
